# %% [markdown]
# EXPLORATORY DATA ANALYSIS OF CAR FEATURES
#
#
# [1]Introduction
#
# Exploratory Data Analysis (EDA) is an approach/philosophy for data analysis that employs a variety of techniques (graphical and quantitative) to better understand data. It is easy to get lost in the visualizations of EDA and to also lose track of the purpose of EDA. EDA aims to make the downstream analysis easier. To put EDA in context, the Data Science steps are: Obtain data, Clean and load data; Exploratory Data Analysis; Model building; Model evaluation; Data visualization and Presentation.
#
#
# Contents:-
# Exploratory data
# analysis on how the different features of a car and its price are related. The data comes
# from the Kaggle dataset "Car Features and MSRP". It describes almost 12,000 car
# models, sold in the USA between 1990 and 2017, with the market price
# and some features.

# %% [markdown]
# [1.1] Importing packages

# %%
import numpy as np                                        #Implements multidimensional array and matrices 
import pandas as pd                                       #for data manipulation and analysis
import matplotlib.pyplot as plt                           #plotting library of python programming languages  
import seaborn as sns                                     #provide high level interface for drawing attractive & informative statistical graphics
# %matplotlib inline 
sns.set()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# [1.2] Importing the dataset

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-953408e0-424d-4ce2-8706-a91096431af1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-953408e0-424d-4ce2-8706-a91096431af1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving EDA.csv to EDA.csv

# %%
import io
car_features = pd.read_csv(io.BytesIO(uploaded['EDA.csv']))                #reading the data from local-drive

# %% [markdown]
# [1.3] Checking datatypes,statustical summary,null values ,shape.

# %%
car_features.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %%
car_features.shape
# Out:
# (11914, 16)

# %%
car_features.head(10)                            #Inspecting the first ten-rows
# Out:
#   Make       Model  Year  ... city mpg  Popularity   MSRP
# 0  BMW  1 Series M  2011  ...       19        3916  46135
# 1  BMW    1 Series  2011  ...       19        3916  40650
# 2  BMW    1 Series  2011  ...       20        3916  36350
# 3  BMW    1 Series  2011  ...       18        3916  29450
# 4  BMW    1 Series  2011  ...       18        3916  34500
# 5  BMW    1 Series  2012  ...       18        3916  31200
# 6  BMW    1 Series  2012  ...       17        3916  44100
# 7  BMW    1 Series  2012  ...       20        3916  39300
# 8  BMW    1 Series  2012  ...       18        3916  36900
# 9  BMW    1 Series  2013  ...       18        3916  37200
#
# [10 rows x 16 columns]

# %%
  #Inspecting the last ten-rows
  car_features.tail(10)
# Out:
#           Make   Model  Year  ... city mpg  Popularity    MSRP
# 11904      BMW      Z8  2002  ...       12        3916  130000
# 11905      BMW      Z8  2003  ...       12        3916  131500
# 11906    Acura     ZDX  2011  ...       16         204   46020
# 11907    Acura     ZDX  2011  ...       16         204   56570
# 11908    Acura     ZDX  2011  ...       16         204   50520
# 11909    Acura     ZDX  2012  ...       16         204   46120
# 11910    Acura     ZDX  2012  ...       16         204   56670
# 11911    Acura     ZDX  2012  ...       16         204   50620
# 11912    Acura     ZDX  2013  ...       16         204   50920
# 11913  Lincoln  Zephyr  2006  ...       17          61   28995
#
# [10 rows x 16 columns]

# %%
car_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %%
car_features.describe()
# Out:
#                Year    Engine HP  ...    Popularity          MSRP
# count  11914.000000  11845.00000  ...  11914.000000  1.191400e+04
# mean    2010.384338    249.38607  ...   1554.911197  4.059474e+04
# std        7.579740    109.19187  ...   1441.855347  6.010910e+04
# min     1990.000000     55.00000  ...      2.000000  2.000000e+03
# 25%     2007.000000    170.00000  ...    549.000000  2.100000e+04
# 50%     2015.000000    227.00000  ...   1385.000000  2.999500e+04
# 75%     2016.000000    300.00000  ...   2009.000000  4.223125e+04
# max     2017.000000   1001.00000  ...   5657.000000  2.065902e+06
#
# [8 rows x 8 columns]

# %% [markdown]
# [2] Removing irrevalent columns
#
# for performing EDA,thses step is most important as there are some of the columns which not useful throughout as compared to others so dropping that columns is best. In these case the columns such as Engine fuel type and Market category.

# %%
car_features = car_features.drop(['Engine Fuel Type','Market Category'], axis = 1)
car_features.head(5)
# Out:
#   Make       Model  Year  Engine HP  ...  highway MPG city mpg Popularity   MSRP
# 0  BMW  1 Series M  2011      335.0  ...           26       19       3916  46135
# 1  BMW    1 Series  2011      300.0  ...           28       19       3916  40650
# 2  BMW    1 Series  2011      300.0  ...           28       20       3916  36350
# 3  BMW    1 Series  2011      230.0  ...           28       18       3916  29450
# 4  BMW    1 Series  2011      230.0  ...           28       18       3916  34500
#
# [5 rows x 14 columns]

# %% [markdown]
# [3] Rename the columns
#
# As ,"Engine HP": "HP", "Engine Cylinders": "Cylinders", "Transmission
# Type": "Transmission", "Driven_Wheels": "Drive Mode","highway MPG": "MPG-H", "city
# mpg": "MPG-C", "MSRP": "Price"

# %%
car_features = car_features.rename(columns={"Engine HP": "HP", "Engine Cylinders": "Cylinders", "Transmission Type": "Transmission", "Driven_Wheels": "Drive Mode","highway MPG": "MPG-H", "city mpg": "MPG-C", "MSRP": "Price"})
car_features.head(10)
# Out:
#   Make       Model  Year     HP  ...  MPG-H MPG-C Popularity  Price
# 0  BMW  1 Series M  2011  335.0  ...     26    19       3916  46135
# 1  BMW    1 Series  2011  300.0  ...     28    19       3916  40650
# 2  BMW    1 Series  2011  300.0  ...     28    20       3916  36350
# 3  BMW    1 Series  2011  230.0  ...     28    18       3916  29450
# 4  BMW    1 Series  2011  230.0  ...     28    18       3916  34500
# 5  BMW    1 Series  2012  230.0  ...     28    18       3916  31200
# 6  BMW    1 Series  2012  300.0  ...     26    17       3916  44100
# 7  BMW    1 Series  2012  300.0  ...     28    20       3916  39300
# 8  BMW    1 Series  2012  230.0  ...     28    18       3916  36900
# 9  BMW    1 Series  2013  230.0  ...     27    18       3916  37200
#
# [10 rows x 14 columns]

# %% [markdown]
# [4] Dropping out the duplicate rows

# %%
car_features.shape
# Out:
# (11914, 14)

# %%
duplicate_rows_car_features = car_features[car_features.duplicated()]
print("Number of duplicate rows: ", duplicate_rows_car_features.shape)
# Out:
# Number of duplicate rows:  (791, 14)

# %% [markdown]
# let us remove the duplicate data because it's ok to remove them.

# %%
car_features.count()                   #used to count the number of rows
# Out:
# Make               11914
# Model              11914
# Year               11914
# HP                 11845
# Cylinders          11884
# Transmission       11914
# Drive Mode         11914
# Number of Doors    11908
# Vehicle Size       11914
# Vehicle Style      11914
# MPG-H              11914
# MPG-C              11914
# Popularity         11914
# Price              11914
# dtype: int64

# %% [markdown]
#  As u can see there are 11914 rows and from these we are removing the 791 rows from the data which are duplicated.

# %%
car_features = car_features.drop_duplicates()
car_features.head(5)
# Out:
#   Make       Model  Year     HP  ...  MPG-H MPG-C Popularity  Price
# 0  BMW  1 Series M  2011  335.0  ...     26    19       3916  46135
# 1  BMW    1 Series  2011  300.0  ...     28    19       3916  40650
# 2  BMW    1 Series  2011  300.0  ...     28    20       3916  36350
# 3  BMW    1 Series  2011  230.0  ...     28    18       3916  29450
# 4  BMW    1 Series  2011  230.0  ...     28    18       3916  34500
#
# [5 rows x 14 columns]

# %%
car_features.shape
# Out:
# (11123, 14)

# %%
car_features.count()
# Out:
# Make               11123
# Model              11123
# Year               11123
# HP                 11054
# Cylinders          11093
# Transmission       11123
# Drive Mode         11123
# Number of Doors    11117
# Vehicle Size       11123
# Vehicle Style      11123
# MPG-H              11123
# MPG-C              11123
# Popularity         11123
# Price              11123
# dtype: int64

# %%
car_features.Transmission.duplicated().sum()                                #As 11118 is no of duplicate for the particular coulmn "Transmission"
# Out:
# 11118

# %% [markdown]
# [4.1] Cleaning (Droping the missing or null values)

# %%
car_features.isnull()                   #count the number of missing values in the data-frame
# Out:
#         Make  Model   Year     HP  ...  MPG-H  MPG-C  Popularity  Price
# 0      False  False  False  False  ...  False  False       False  False
# 1      False  False  False  False  ...  False  False       False  False
# 2      False  False  False  False  ...  False  False       False  False
# 3      False  False  False  False  ...  False  False       False  False
# 4      False  False  False  False  ...  False  False       False  False
# ...      ...    ...    ...    ...  ...    ...    ...         ...    ...
# 11909  False  False  False  False  ...  False  False       False  False
# 11910  False  False  False  False  ...  False  False       False  False
# 11911  False  False  False  False  ...  False  False       False  False
# 11912  False  False  False  False  ...  False  False       False  False
# 11913  False  False  False  False  ...  False  False       False  False
#
# [11123 rows x 14 columns]

# %%
car_features.isnull().sum()                          #count the number of missing values in each columns
# Out:
# Make                0
# Model               0
# Year                0
# HP                 69
# Cylinders          30
# Transmission        0
# Drive Mode          0
# Number of Doors     6
# Vehicle Size        0
# Vehicle Style       0
# MPG-H               0
# MPG-C               0
# Popularity          0
# Price               0
# dtype: int64

# %% [markdown]
# This is the reason in the above step while counting for Cylinders , Horsepower (HP) and Number of Doors had 69, 30 and 6 these much numbers of missing values.

# %%
car_features = car_features.dropna()                             #dropping the missing values which ever got from the previous                                                                  
car_features.count()                                             #removed all rows from the data which contains the missing values /null values for hp, cylinders and number of doors
# Out:
# Make               11024
# Model              11024
# Year               11024
# HP                 11024
# Cylinders          11024
# Transmission       11024
# Drive Mode         11024
# Number of Doors    11024
# Vehicle Size       11024
# Vehicle Style      11024
# MPG-H              11024
# MPG-C              11024
# Popularity         11024
# Price              11024
# dtype: int64

# %%
print(car_features.isnull().sum())                                    #After dropping all the values
# Out:
# Make               0
# Model              0
# Year               0
# HP                 0
# Cylinders          0
# Transmission       0
# Drive Mode         0
# Number of Doors    0
# Vehicle Size       0
# Vehicle Style      0
# MPG-H              0
# MPG-C              0
# Popularity         0
# Price              0
# dtype: int64

# %% [markdown]
# [5]Removing the outliers

# %%
sns.boxplot(x=car_features['Year'])

# %%
plt.rcParams['figure.figsize']=(23,10)
ax = sns.boxplot(x="Make", y="Price", data=car_features)

# %%
plt.rcParams['figure.figsize']=(19,7)
ax = sns.boxplot(x="Year", y="Price", data=car_features)

# %%
sns.boxplot(x=car_features['Popularity'])

# %%
sns.boxplot(x=car_features['MPG-H'])

# %%
sns.boxplot(x=car_features['MPG-C'])

# %%
Q1 = car_features.quantile(0.25)
Q3 = car_features.quantile(0.75)
IQR = Q3 - Q1
print(IQR)                                                #Calculating the IQR
# Out:
# Year                   9.00
# HP                   131.00
# Cylinders              2.00
# Number of Doors        2.00
# MPG-H                  8.00
# MPG-C                  6.00
# Popularity          1460.00
# Price              21426.25
# dtype: float64

# %% [markdown]
# Detect the outlier using IQR but now we want to remove or filter the outliers and get the clean data,this can be done as:

# %%
car_features = car_features[~((car_features < (Q1 - 1.5 * IQR)) |(car_features > (Q3 + 1.5 * IQR))).any(axis=1)]
car_features.shape
# Out:
# (8547, 14)

# %% [markdown]
# [6]Checking for the top brands of car

# %%
car_features.Make.value_counts().head(10).plot.bar()
plt.title("Top 10 car brands on sale")
# Out:
# Text(0.5, 1.0, 'Top 10 car brands on sale')

# %%
prices = car_features[['Make','Price']].loc[(car_features['Make'] == 'chevrolet')|
                        (car_features['Make'] == 'Ford')|
                        (car_features['Make'] == 'Volkswagen')|
                        (car_features['Make'] == 'Toyota')|
                        (car_features['Make'] == 'Dodge')|
                        (car_features['Make'] == 'Nissan')|
                        (car_features['Make'] == 'GMC')|
                        (car_features['Make'] == 'Honda')|
                        (car_features['Make'] == 'Mazda')].groupby('Make').mean()
print(prices)
# Out:
#                    Price
# Make
# Dodge       26076.722353
# GMC         33261.400853
# Honda       27381.364611
# Mazda       20495.820106
# Nissan      28352.543860
# Toyota      27769.421793
# Volkswagen  29032.817476

# %% [markdown]
# [7]Correlation Matrix

# %%
car_features.corr()
# Out:
#                      Year        HP  Cylinders  ...     MPG-C  Popularity     Price
# Year             1.000000  0.325184  -0.106680  ...  0.335334    0.200925  0.591630
# HP               0.325184  1.000000   0.734026  ... -0.554664    0.095246  0.745829
# Cylinders       -0.106680  0.734026   1.000000  ... -0.746367    0.013311  0.388860
# Number of Doors  0.240495  0.041088   0.020398  ...  0.025387   -0.076300  0.130451
# MPG-H            0.373376 -0.453371  -0.691404  ...  0.936981    0.093082 -0.121085
# MPG-C            0.335334 -0.554664  -0.746367  ...  1.000000    0.081209 -0.197101
# Popularity       0.200925  0.095246   0.013311  ...  0.081209    1.000000  0.113827
# Price            0.591630  0.745829   0.388860  ... -0.197101    0.113827  1.000000
#
# [8 rows x 8 columns]

# %% [markdown]
# There is a high correlation in betwwen HP-Cylinders, HP-Price, and negative strong correlation in between highway mpg with highway and city MPG because lower MPG figures mean higher fuel.

# %%
import seaborn as sns
corr = car_features.corr()
plt.figure(figsize=(20,9))
a = sns.heatmap(corr, annot=True, fmt='.2f')

# %%
car_features.Make.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
plt.title("Number of cars by make")
plt.ylabel('Number of cars')
plt.xlabel('Make');

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(car_features['HP'], car_features['Year'])
ax.set_xlabel('HP')
ax.set_ylabel('Year')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
g = sns.pairplot(car_features[["MPG-H", "HP", "Popularity", "Cylinders","Price", "Year"]], hue="Year", diag_kind="hist")

# %%
sns.countplot(y='Vehicle Style',data=car_features, hue='Drive Mode')
plt.title("Vehicle Type v/s Drive mode Type")
plt.ylabel('Vehicle Type')
plt.xlabel('Count of vehicles')
# Out:
# Text(0.5, 0, 'Count of vehicles')

# %% [markdown]
# [8] Different graphs

# %%
car_features[['MPG-H','MPG-C','Year','HP','Price']].hist(figsize=(10,8),bins=6,color='Y')
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/hist.py:404: MatplotlibDeprecationWarning: Support for uppercase single-letter colors is deprecated since Matplotlib 3.1 and will be removed in 3.3; please use lowercase instead.
#   ax.hist(data[col].dropna().values, bins=bins, **kwds)

# %%
plt.figure(1)
plt.subplot(221)
car_features['Vehicle Style'].value_counts(normalize=True).plot(figsize=(10,8),kind='bar',color='red')
plt.title("Number of vehicle style frequency diagram")
plt.ylabel('Number of vehicle style')
plt.xlabel('Vehicle Style');


plt.subplot(222)
car_features['Number of Doors'].value_counts(normalize=True).plot(figsize=(10,8),kind='bar',color='green')
plt.title("number of Door frequency diagram")
plt.ylabel('number of Doors')
plt.xlabel('Number of Doors');

# %%
plt.subplot(223)
car_features['Vehicle Size'].value_counts(normalize= True).plot(figsize=(10,8),kind='bar',color='purple')
plt.title("Number of vehicle size frequency diagram")
plt.ylabel('Number of vehicles')
plt.xlabel('Vehicle Size');

plt.subplot(224)
car_features['Drive Mode'].value_counts(normalize=True).plot(figsize=(10,8),kind='bar',color='orange')
plt.title("Number of drive mode frequency diagram")
plt.ylabel('Number of vehicles')
plt.xlabel('Drive Mode');
plt.tight_layout()
plt.show()
